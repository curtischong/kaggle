# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# %matplotlib inline
import matplotlib.pyplot as plt  # Matlab-style plotting
import seaborn as sns
color = sns.color_palette()
sns.set_style('darkgrid')
import warnings
def ignore_warn(*args, **kwargs):
    pass
warnings.warn = ignore_warn #ignore annoying warning (from sklearn and seaborn)


from scipy import stats
from scipy.stats import norm, skew #for some statistics


pd.set_option('display.float_format', lambda x: '{:.3f}'.format(x)) #Limiting floats output to 3 decimal points

# %%
train = pd.read_csv("sales_train.csv")
train.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154     999.000         1.000
# 1  03.01.2013               0       25     2552     899.000         1.000
# 2  05.01.2013               0       25     2552     899.000        -1.000
# 3  06.01.2013               0       25     2554    1709.050         1.000
# 4  15.01.2013               0       25     2555    1099.000         1.000

# %%
train.groupby(["item_id"]).item_price.agg([len])[:5]
# Out:
#           len
# item_id
# 0       1.000
# 1       6.000
# 2       2.000
# 3       2.000
# 4       1.000

# %%
train[(train["item_id"] ==22140)].sort_values(by="shop_id")
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 1972636  01.09.2014              20       54        0      58.000
#
#          item_cnt_day
# 1972636         1.000

# %% [markdown]
# I think I should add an item_price column. It should be imputed based on the date, shop_id, and item_id

# %%
train = pd.read_csv("sales_train.csv")
test = pd.read_csv("test.csv")
items = pd.read_csv("items.csv")
itemsCat = pd.read_csv("item_categories.csv")
shops = pd.read_csv("shops.csv")

import math
def get_second(strings):
    if isinstance(strings, str):
        temp = strings.split(" - ")
        if len(temp) > 1:
            return temp[1].strip()
        return "NA"
    return "NA"
def get_first(strings):
    if isinstance(strings, str):
        temp = strings.split(" - ")
        return temp[0].strip()
    return "NA"

train = train.merge(items, left_on='item_id', right_on='item_id', how='outer')
train = train.merge(itemsCat, left_on='item_category_id', right_on='item_category_id', how='outer')
train = trai`n.merge(shops, left_on='shop_id', right_on='shop_id', how='outer')
train.drop(["item_id","item_category_id","shop_id"],axis=1, errors="ignore",inplace=True)
train["cat1"] = train.item_category_name.map(lambda x: x.split(" - ")[0].strip())
train["cat2"] = train.item_category_name.map(lambda x: get_second(x))

test = test.merge(items, left_on='item_id', right_on='item_id', how='outer')
test = test.merge(itemsCat, left_on='item_category_id', right_on='item_category_id', how='outer')
test = test.merge(shops, left_on='shop_id', right_on='shop_id', how='outer')
test.drop(["item_id","item_category_id","shop_id"],axis=1, errors="ignore",inplace=True)
test["cat1"] = test.item_category_name.map(lambda x: get_first(x))
test["cat2"] = test.item_category_name.map(lambda x: get_second(x))
# Out:
# 'train = train.merge(items, left_on=\'item_id\', right_on=\'item_id\', how=\'outer\')\ntrain = train.merge(itemsCat, left_on=\'item_category_id\', right_on=\'item_category_id\', how=\'outer\')\ntrain = trai`n.merge(shops, left_on=\'shop_id\', right_on=\'shop_id\', how=\'outer\')\ntrain.drop(["item_id","item_category_id","shop_id"],axis=1, errors="ignore",inplace=True)\ntrain["cat1"] = train.item_category_name.map(lambda x: x.split(" - ")[0].strip())\ntrain["cat2"] = train.item_category_name.map(lambda x: get_second(x))\n\ntest = test.merge(items, left_on=\'item_id\', right_on=\'item_id\', how=\'outer\')\ntest = test.merge(itemsCat, left_on=\'item_category_id\', right_on=\'item_category_id\', how=\'outer\')\ntest = test.merge(shops, left_on=\'shop_id\', right_on=\'shop_id\', how=\'outer\')\ntest.drop(["item_id","item_category_id","shop_id"],axis=1, errors="ignore",inplace=True)\ntest["cat1"] = test.item_category_name.map(lambda x: get_first(x))\ntest["cat2"] = test.item_category_name.map(lambda x: get_second(x))'

# %%
#I think I can drop item_category_name. We'll see how well it fares w/ and w/o it
train.head()
# Out:
#          date  date_block_num  item_price  item_cnt_day          item_name  \
# 0  02.01.2013           0.000     999.000         1.000  ЯВЛЕНИЕ 2012 (BD)
# 1  26.04.2013           3.000     150.000         1.000          2012 (BD)
# 2  26.06.2013           5.000     199.500         1.000          2012 (BD)
# 3  20.07.2013           6.000     199.500         1.000          2012 (BD)
# 4  14.09.2013           8.000     299.000         2.000          2012 (BD)
#
#   item_category_name               shop_name  cat1     cat2
# 0     Кино - Blu-Ray  Ярославль ТЦ "Альтаир"  Кино  Blu-Ray
# 1     Кино - Blu-Ray  Ярославль ТЦ "Альтаир"  Кино  Blu-Ray
# 2     Кино - Blu-Ray  Ярославль ТЦ "Альтаир"  Кино  Blu-Ray
# 3     Кино - Blu-Ray  Ярославль ТЦ "Альтаир"  Кино  Blu-Ray
# 4     Кино - Blu-Ray  Ярославль ТЦ "Альтаир"  Кино  Blu-Ray

# %%
#I am predicting for november 2015
test.head()
# Out:
#       ID                                          item_name  \
# 0  0.000                     NHL 15 [PS3, русские субтитры]
# 1  2.000  Need for Speed Rivals (Essentials) [PS3, русск...
# 2 15.000  Minecraft. Playstation 3 Edition [PS3, русская...
# 3 21.000               NBA 2K16 [PS3, русская документация]
# 4 23.000  Plants vs. Zombies Garden Warfare [PS3, русска...
#
#   item_category_name               shop_name  cat1 cat2
# 0         Игры - PS3  Вологда ТРЦ "Мармелад"  Игры  PS3
# 1         Игры - PS3  Вологда ТРЦ "Мармелад"  Игры  PS3
# 2         Игры - PS3  Вологда ТРЦ "Мармелад"  Игры  PS3
# 3         Игры - PS3  Вологда ТРЦ "Мармелад"  Игры  PS3
# 4         Игры - PS3  Вологда ТРЦ "Мармелад"  Игры  PS3

# %% [markdown]
# Things to investigate:
#  - the annual trends
#  - the monthly trends
#  - the day of week trends
#  - anything major that might've happened in russia in november
#      - local news?
#
# Ideas for dates:
#  - is_weekend
#  - is_holiday (are there russian holidays in november?)
#
# The problem is that there isn't a date in the test dataset.
# ideas:
#  - have 2 models. One specifically for November, one for the whole year
#  - November has a weight of 70% and the year one will have a weight of 30%

# %%
def get_year(strings):
    if isinstance(strings, str):
        temp = strings.split(".")
        if len(temp) > 2:
            return temp[2]
        return -1
    return -1
def get_month(strings):
    if isinstance(strings, str):
        temp = strings.split(".")
        if len(temp) > 1:
            return temp[1]
        return -1
    return -1

train["year"] = train.date.map(lambda x: get_year(x))
train["month"] = train.date.map(lambda x: get_month(x))
train = train[train["month"] != -1]
train.head()
# Out:
#          date  date_block_num  item_price  item_cnt_day          item_name  \
# 0  02.01.2013           0.000     999.000         1.000  ЯВЛЕНИЕ 2012 (BD)
# 1  26.04.2013           3.000     150.000         1.000          2012 (BD)
# 2  26.06.2013           5.000     199.500         1.000          2012 (BD)
# 3  20.07.2013           6.000     199.500         1.000          2012 (BD)
# 4  14.09.2013           8.000     299.000         2.000          2012 (BD)
#
#   item_category_name               shop_name  cat1     cat2  year month
# 0     Кино - Blu-Ray  Ярославль ТЦ "Альтаир"  Кино  Blu-Ray  2013    01
# 1     Кино - Blu-Ray  Ярославль ТЦ "Альтаир"  Кино  Blu-Ray  2013    04
# 2     Кино - Blu-Ray  Ярославль ТЦ "Альтаир"  Кино  Blu-Ray  2013    06
# 3     Кино - Blu-Ray  Ярославль ТЦ "Альтаир"  Кино  Blu-Ray  2013    07
# 4     Кино - Blu-Ray  Ярославль ТЦ "Альтаир"  Кино  Blu-Ray  2013    09

# %%
train.drop(["date","date_block_num","item_category_name"],axis=1,inplace=True,errors="ignore")
test.drop(["item_category_name"],axis=1,inplace=True,errors="ignore")
test["year"] = 2015
test["month"] = 11
train.head()
# Out:
#    item_price  item_cnt_day          item_name               shop_name  cat1  \
# 0     999.000         1.000  ЯВЛЕНИЕ 2012 (BD)  Ярославль ТЦ "Альтаир"  Кино
# 1     150.000         1.000          2012 (BD)  Ярославль ТЦ "Альтаир"  Кино
# 2     199.500         1.000          2012 (BD)  Ярославль ТЦ "Альтаир"  Кино
# 3     199.500         1.000          2012 (BD)  Ярославль ТЦ "Альтаир"  Кино
# 4     299.000         2.000          2012 (BD)  Ярославль ТЦ "Альтаир"  Кино
#
#       cat2  year month
# 0  Blu-Ray  2013    01
# 1  Blu-Ray  2013    04
# 2  Blu-Ray  2013    06
# 3  Blu-Ray  2013    07
# 4  Blu-Ray  2013    09

# %%
test.head()
# Out:
#       ID                                          item_name  \
# 0  0.000                     NHL 15 [PS3, русские субтитры]
# 1  2.000  Need for Speed Rivals (Essentials) [PS3, русск...
# 2 15.000  Minecraft. Playstation 3 Edition [PS3, русская...
# 3 21.000               NBA 2K16 [PS3, русская документация]
# 4 23.000  Plants vs. Zombies Garden Warfare [PS3, русска...
#
#                 shop_name  cat1 cat2  year  month
# 0  Вологда ТРЦ "Мармелад"  Игры  PS3  2015     11
# 1  Вологда ТРЦ "Мармелад"  Игры  PS3  2015     11
# 2  Вологда ТРЦ "Мармелад"  Игры  PS3  2015     11
# 3  Вологда ТРЦ "Мармелад"  Игры  PS3  2015     11
# 4  Вологда ТРЦ "Мармелад"  Игры  PS3  2015     11

# %%
train.to_pickle("ftrain")
test.to_pickle("ftest")
