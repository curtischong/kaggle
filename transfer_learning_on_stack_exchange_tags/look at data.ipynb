# %%
import pandas as pd
from bs4 import BeautifulSoup

# %%
biology = pd.read_csv("biology.csv")
cooking = pd.read_csv("cooking.csv")
crypto = pd.read_csv("crypto.csv")
diy = pd.read_csv("diy.csv")
robotics = pd.read_csv("robotics.csv")
test = pd.read_csv("test.csv")
travel = pd.read_csv("travel.csv")

# %% [markdown]
# My plan: go through every row and vectorize everything. bag of words baby.
# I can train multiple binary classifiers.
# - yes = the class I'm training to look out for
# - no = all the other classes that I have.
#
# or I can use this:
# http://scikit-learn.org/stable/modules/multiclass.html

# %%
#amazing code from http://www.grant-mckinnon.com/?p=17
import re
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
 
def clean_txt(s):
    if isinstance(s, str):
        s = s.lower()
        s = s.replace("//"," ")
        s = s.replace("..",".")
        s = s.replace(" / "," ")
        s = s.replace("/"," ")
        s = s.replace(" \\ "," ")
        s = s.replace("."," . ")
        s = s.replace(" . "," ")
        s = s.replace("("," ")
        s = s.replace(")"," ")
        s = s.replace("\n"," ")
        s = s.replace(" "," ")
        s = re.sub("[^a-zA-Z]"," ", s)
        s = (" ").join([wordnet_lemmatizer.lemmatize(z) for z in s.split(" ")])
        return s
    else:
        return "null"

# %%
biology.content = biology.content.map(lambda x: clean_txt(BeautifulSoup(x, "html.parser").text))
cooking.content = cooking.content.map(lambda x: clean_txt(BeautifulSoup(x, "html.parser").text))
crypto.content = crypto.content.map(lambda x: clean_txt(BeautifulSoup(x, "html.parser").text))
diy.content = diy.content.map(lambda x: clean_txt(BeautifulSoup(x, "html.parser").text))
robotics.content = robotics.content.map(lambda x: clean_txt(BeautifulSoup(x, "html.parser").text))
test.content = test.content.map(lambda x: clean_txt(BeautifulSoup(x, "html.parser").text))
travel.content = travel.content.map(lambda x: clean_txt(BeautifulSoup(x, "html.parser").text))

# %%
#seems like this dataset is complete
biology[biology.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [id, title, content, tags]
# Index: []

# %%
sample_submission = pd.read_csv("sample_submission.csv")
sample_submission
# Out:
#            id            tags
# 0           1  physics poetry
# 1           2  physics poetry
# 2           3  physics poetry
# 3           7  physics poetry
# 4           9  physics poetry
# 5          13  physics poetry
# 6          15  physics poetry
# 7          17  physics poetry
# 8          19  physics poetry
# 9          21  physics poetry
# 10         24  physics poetry
# 11         26  physics poetry
# 12         27  physics poetry
# 13         29  physics poetry
# 14         31  physics poetry
# 15         32  physics poetry
# 16         35  physics poetry
# 17         37  physics poetry
# 18         41  physics poetry
# 19         49  physics poetry
# 20         52  physics poetry
# 21         62  physics poetry
# 22         68  physics poetry
# 23         71  physics poetry
# 24         72  physics poetry
# 25         73  physics poetry
# 26         75  physics poetry
# 27         78  physics poetry
# 28         79  physics poetry
# 29         83  physics poetry
# ...       ...             ...
# 81896  278070  physics poetry
# 81897  278071  physics poetry
# 81898  278075  physics poetry
# 81899  278077  physics poetry
# 81900  278079  physics poetry
# 81901  278080  physics poetry
# 81902  278081  physics poetry
# 81903  278084  physics poetry
# 81904  278086  physics poetry
# 81905  278088  physics poetry
# 81906  278091  physics poetry
# 81907  278092  physics poetry
# 81908  278093  physics poetry
# 81909  278095  physics poetry
# 81910  278096  physics poetry
# 81911  278099  physics poetry
# 81912  278101  physics poetry
# 81913  278107  physics poetry
# 81914  278108  physics poetry
# 81915  278109  physics poetry
# 81916  278111  physics poetry
# 81917  278113  physics poetry
# 81918  278116  physics poetry
# 81919  278117  physics poetry
# 81920  278118  physics poetry
# 81921  278119  physics poetry
# 81922  278120  physics poetry
# 81923  278121  physics poetry
# 81924  278124  physics poetry
# 81925  278126  physics poetry
#
# [81926 rows x 2 columns]
